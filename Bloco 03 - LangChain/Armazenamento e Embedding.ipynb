# %%
# !pip install -U langchain-openai

# %%
from langchain_openai import OpenAIEmbeddings

import os

# %%
OPENAI_API_KEY = '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'

os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
embedding = OpenAIEmbeddings()

# %%
sentence1 = "Eu gosto de cachorros."

# %%
## criando o vetor
embedding1 = embedding.embed_query(sentence1)

# %%
print(embedding1)
# Out:
# [-0.012904486618936062, 0.0014179822755977511, -0.00616849260404706, -0.027684194967150688, -0.0170127023011446, 0.010258203372359276, 0.008500183001160622, -0.016321832314133644, 0.005782961845397949, -0.0010833415435627103, 0.00838914979249239, 0.006816184613853693, -0.00415139552205801, -0.03385268896818161, -0.0030580302700400352, 0.012990845367312431, 0.03678889200091362, -0.007790806237608194, 0.014520632103085518, -0.006452243309468031, 0.012818127870559692, 0.0004078915808349848, 0.012497366406023502, -0.030595723539590836, -0.025266146287322044, 0.004873109515756369, 0.009925104677677155, -0.013644706457853317, 0.01554460171610117, -0.02521679922938347, 0.037010956555604935, -0.00571202440187335, -0.021787116304039955, -0.013558346778154373, -0.012306143529713154, -0.03669019415974617, 0.01471802406013012, -0.007167788688093424, -0.005110596306622028, -0.0028637228533625603, -0.010270540602505207, 0.010486437939107418, 0.0038090443704277277, -0.02473565563559532, 0.005607159
# ...

# %% [markdown]
# ## Comparação de embeddings

# %%
sentence2 = "Eu gosto de cães."
embedding2 = embedding.embed_query(sentence2)

# %%
print(embedding2)
# Out:
# [-0.020006002858281136, 0.001277389470487833, -0.013040950521826744, -0.027020452544093132, -0.01572076603770256, 0.01722739078104496, 0.002584108617156744, -0.010416706092655659, 0.0009069079533219337, -0.008811285719275475, 0.004109257832169533, 0.011775137856602669, 0.00546769006177783, -0.030379485338926315, -0.010589596815407276, 0.015177393332123756, 0.032182496041059494, -0.00020800995116587728, 0.013794262893497944, -0.007594871334731579, 0.01446112897247076, 0.0002329016715520993, 0.015782512724399567, -0.03003370389342308, -0.00867544300854206, 0.00887303240597248, 0.010564898140728474, -0.003281848970800638, 0.01496745366603136, -0.02226594090461731, 0.03749272972345352, -0.003834483912214637, -0.028897559270262718, -0.018808113411068916, -0.0025393422693014145, -0.03146623075008392, 0.02357497438788414, 0.003939453512430191, -0.001690321951173246, -0.005949316080659628, -0.014720465987920761, 0.01203447487205267, 0.009002701379358768, -0.026254791766405106, 0.016264138743
# ...

# %%
## Comparando as frases
import numpy as np

similarity = np.dot(embedding1, embedding2)

similarity
# Out:
# 0.9734449815985107

# %%
sentence3 = "O tempo está feio lá fora."
embedding3 = embedding.embed_query(sentence3)

similarity = np.dot(embedding1, embedding3)

similarity
# Out:
# 0.7907968793451248

# %% [markdown]
# ### Armazenamento vetorial

# %%
# !pip install langchain
# !pip install -U langchain-community
# !pip install pypdf
# !pip install chromadb

# %%
from langchain.vectorstores import Chroma
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings

# %%
loaders = [
    PyPDFLoader("PequenosSatelitesGrandesPossibilidades-Cap1.pdf"),
    PyPDFLoader("PequenosSatelitesGrandesPossibilidades-Cap2.pdf"),
    PyPDFLoader("PequenosSatelitesGrandesPossibilidades-Cap3.pdf")
]

docs = []
for loader in loaders:
    docs.extend(loader.load())

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=150)
splits = text_splitter.split_documents(docs)

# %%
persist_directory = 'docs/chroma/'

# %%
embedding = OpenAIEmbeddings()

# %%
## Armarzenamento com o BD Chroma
vectordb = Chroma.from_documents(documents=splits, embedding=embedding, persist_directory=persist_directory)

# %%
print(vectordb._collection.count())
# Out:
# 644

# %% [markdown]
# ## Busca por Similaridade

# %%
question = "O que foi dito sobre missões educacionais nos satélites?"

# %%
doc = vectordb.similarity_search(question, k=1)
print(doc[0].page_content)
# Out:
# nicação e imageamento com nanossatélites e fomentar projetos na área espacial. Sua
# principal missão foi capacitar recursos humanos para projetos de aplicação espacial, com
# foco na integração de soluções disponíveis ao invés do desenvolvimento de subsistemas
# do satélite.
# 1.2 Missões e aplicações de satélites
# Os principais fatores que impulsionam a adoção mundial e o crescimento dos Cube-
# Sats podem ser resumidos em, [6]:
# • Possibilidade de atingir diversos objetivos de diferentes missões;
# • Possibilidade de ser carga secundária de uma missão maior e de permanecer em
# órbitas e localizações distintas;
# Pequenos satélites: grandes possibilidades
