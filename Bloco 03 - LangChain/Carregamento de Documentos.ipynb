# %%
# %pip install openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import openai

# %%
import os

# %%
OPENAI_API_KEY = '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'

# %%
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %% [markdown]
# ## PDFs

# %%
# %pip install langchain
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U langchain-community
# Out:
# ...
#
# ...

# %%
# %pip install pypdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("./files/PequenosSatelitesGrandesPossibilidades-Cap1.pdf")
pages = loader.load()

# %%
## quantidade de páginas que tem o documento
print(len(pages))
# Out:
# 16

# %%
## conteúdo da primeira página
print(pages[0].page_content)
# Out:
# 1. Introdução
# Wesley Flavio Gueta (UFSCar)
# Augusto Almeida de Jesus (UFSCar)
# Rafael Vidal Aroca (UFSCar)
# Calvin Trubiene (PION)
# Bruno Pinto Costa (PION)
# 1.1 Introdução
# Estamos habituados à ideia de satélite natural. Exemplos cotidianos e próximos são:
# a Lua como um satélite da Terra e a Terra um satélite que orbita o Sol. Satélite refere-se
# a um corpo que orbita outro por inﬂuência gravitacional. Dessa forma, podemos deﬁnir
# satélites artiﬁciais como algo mecânico lançado ao espaço e que orbita um corpo celeste,
# como a Terra [1]. Mais especiﬁcamente, podemos compreendê-los como sistemas semi-
# independentes controlados por computador e equipados com instrumentos adequados
# para viabilizar o objetivo da missão que pode ser de natureza cientíﬁca ou tecnológica.
# Assim como temos a Lua e a Terra como satélites naturais que nos vem rapidamente
# à mente, com o lançamento de satélites artiﬁciais cada vez mais frequentes, e milhares
# ...

# %%
## metadados relacionados a esta página (informações extras relacionadas ao documento)
print(pages[0].metadata)
# Out:
# {'source': './files/PequenosSatelitesGrandesPossibilidades-Cap1.pdf', 'page': 0}

# %%
## tipo de dados
print(type(pages[0]))
# Out:
# <class 'langchain_core.documents.base.Document'>

# %% [markdown]
# ## Audio YouTube

# %%
# %pip install yt_dlp
# %pip install pydub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.document_loaders.generic import GenericLoader
from langchain.document_loaders.parsers import OpenAIWhisperParser
from langchain.document_loaders.blob_loaders.youtube_audio import YoutubeAudioLoader

# %%
url = "https://www.youtube.com/watch?v=Iv9uAQntCBI"

# %%
save_dir = "docs/youtube/"

# %%
loader = GenericLoader(
    YoutubeAudioLoader([url], save_dir),
    OpenAIWhisperParser()
)

# %%
docs = loader.load()
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Iv9uAQntCBI
# [youtube] Iv9uAQntCBI: Downloading webpage
# [youtube] Iv9uAQntCBI: Downloading ios player API JSON
# [youtube] Iv9uAQntCBI: Downloading mweb player API JSON
# [youtube] Iv9uAQntCBI: Downloading m3u8 information
# [info] Iv9uAQntCBI: Downloading 1 format(s): 140
# [download] docs\youtube\PARTÍCULAS MAIS RÁPIDAS QUE A LUZ FARIAM PARTE DO PROCESSO DE FORMAÇÃO DA MATÉRIA, DIZEM FÍSICOS.m4a has already been downloaded
# [download] 100% of    5.41MiB
# [ExtractAudio] Not converting audio docs\youtube\PARTÍCULAS MAIS RÁPIDAS QUE A LUZ FARIAM PARTE DO PROCESSO DE FORMAÇÃO DA MATÉRIA, DIZEM FÍSICOS.m4a; file is already in target format m4a
# Transcribing part 1!

# %%
## visualizando o conteúdo (500 primeiros caracteres)
print(docs[0].page_content[:500])
# Out:
# Táquions são partículas, pelo menos até hoje, hipotéticas, que viajam a velocidades maiores que a da luz. Essas partículas superluminais, até recentemente, eram consideradas impossíveis pela teoria física predominante. Mas um novo artigo, recém-publicado na Physical Review de Por Físicos da Universidade de Oxford e de Varsóvia, mostrou que muitas dessas proibições teóricas eram infundadas. Os táquions não apenas não são descartados pela teoria, mas nos permitem entender melhor sua estrutura caus

# %% [markdown]
# ## Carregamento de URLs

# %%
# %pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.document_loaders import WebBaseLoader

# %%
loader = WebBaseLoader("https://g1.globo.com/ciencia/noticia/2024/06/27/nasa-escolhe-spacex-para-tirar-a-estacao-espacial-internacional-de-orbita-em-2030.ghtml")

# %%
docs_site = loader.load()

# %%
print(docs_site[0].page_content[:500])
# Out:
#  Nasa escolhe SpaceX para tirar a Estação Espacial Internacional de órbita em 2030 | Ciência | G1
# A estação espacial é retratada pelo SpaceX Crew Dra              Nasa escolhe SpaceX para tirar a Estação Espacial Internacional de órbita em 2030    Estação Espacial Internacional orbita a Terra desde o início da sua construção, em 1998.        Por g1    27/06/2024 11h48    Atualizado  27/06/2024                                              1 de 2
